# %%
import pandas as pd
from pathlib import Path

# %%
#store filepaths as a variable
file1 = Path("Resources/202410/202410-citibike-tripdata_1.csv")
file2 = Path("Resources/202410/202410-citibike-tripdata_2.csv")
file3 = Path("Resources/202410/202410-citibike-tripdata_3.csv")
file4 = Path("Resources/202410/202410-citibike-tripdata_4.csv")
file5 = Path("Resources/202410/202410-citibike-tripdata_5.csv")
file6 = Path("Resources/202410/202410-citibike-tripdata_6.csv")

# %%
#read data files with pandas library
file1_df = pd.read_csv(file1, low_memory=False)
file2_df = pd.read_csv(file2, low_memory=False)
file3_df = pd.read_csv(file3, low_memory=False)
file4_df = pd.read_csv(file4, low_memory=False)
file5_df = pd.read_csv(file5, low_memory=False)
file6_df = pd.read_csv(file5, low_memory=False)

# %%
file1_df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  B4544C93905FA10E  electric_bike  2024-10-13 17:38:36.748
# 1  435860FFE89FC278  electric_bike  2024-10-06 00:58:33.042
# 2  4EB0709C97181E8A  electric_bike  2024-10-11 21:15:40.455
# 3  930590FEA1806C34  electric_bike  2024-10-14 19:08:12.154
# 4  EA33E5FD386A60F4  electric_bike  2024-10-13 01:19:20.877
#
#                   ended_at          start_station_name start_station_id  \
# 0  2024-10-13 17:45:22.657       Rutgers St & Henry St          5230.02
# 1  2024-10-06 01:02:46.775   Washington Ave & E 167 St          8068.01
# 2  2024-10-11 21:46:54.286  E Fordham Rd & Webster Ave          8582.09
# 3  2024-10-14 19:30:24.011   Washington Ave & E 167 St          8068.01
# 4  2024-10-13 01:29:47.343  E Fordham Rd & Webster Ave          8582.09
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0             Lafayette St & Grand St        5422.09  40.713322 -73.990097
# ...

# %%
combined_df = pd.concat([file1_df, file2_df, file3_df, file4_df, file5_df, file6_df], ignore_index=True)
combined_df.tail()
# Out:
#                   ride_id  rideable_type               started_at  \
# 5999995  5CB654F38B775791  electric_bike  2024-10-28 17:05:05.665
# 5999996  96F001FC414D0497   classic_bike  2024-10-20 09:16:52.418
# 5999997  2231AFFBF82B6BB9   classic_bike  2024-10-28 13:43:27.523
# 5999998  85C991784F68B501  electric_bike  2024-10-30 20:50:42.017
# 5999999  0C7236D88ACB3212  electric_bike  2024-10-14 21:58:34.532
#
#                         ended_at               start_station_name  \
# 5999995  2024-10-28 17:22:51.509  Goulden Ave & Bedford Park Blvd
# 5999996  2024-10-20 09:26:58.060         Fulton St & Clermont Ave
# 5999997  2024-10-28 14:16:00.499         Greenwich St & Hubert St
# 5999998  2024-10-30 20:52:06.200     Prospect Ave & Vanderbilt St
# 5999999  2024-10-14 22:17:38.901          Mercer St & Bleecker St
#
#         start_station_id          end_station_name end_station_id  start_lat  \
# 5999995          8738.01   Riverside Dr & Broadway        8616.06  40.873870
# ...

# %%
row_count = combined_df.shape[0]
print(row_count)
# Out:
# 6000000

# %%
row_count = cleaned_combined_df.shape[0]
print(row_count)combined_df = combined_df.dropna()
cleaned_combined_df.tail()
# Out:
#                   ride_id  rideable_type               started_at  \
# 5999995  5CB654F38B775791  electric_bike  2024-10-28 17:05:05.665
# 5999996  96F001FC414D0497   classic_bike  2024-10-20 09:16:52.418
# 5999997  2231AFFBF82B6BB9   classic_bike  2024-10-28 13:43:27.523
# 5999998  85C991784F68B501  electric_bike  2024-10-30 20:50:42.017
# 5999999  0C7236D88ACB3212  electric_bike  2024-10-14 21:58:34.532
#
#                         ended_at               start_station_name  \
# 5999995  2024-10-28 17:22:51.509  Goulden Ave & Bedford Park Blvd
# 5999996  2024-10-20 09:26:58.060         Fulton St & Clermont Ave
# 5999997  2024-10-28 14:16:00.499         Greenwich St & Hubert St
# 5999998  2024-10-30 20:52:06.200     Prospect Ave & Vanderbilt St
# 5999999  2024-10-14 22:17:38.901          Mercer St & Bleecker St
#
#         start_station_id          end_station_name end_station_id  start_lat  \
# 5999995          8738.01   Riverside Dr & Broadway        8616.06  40.873870
# ...

# %%
row_count = cleaned_combined_df.shape[0]
print(row_count)
# Out:
# 5982290

# %%
sample_202410_df = combined_df.sample(frac=0.05)

# %%
row_count = sample_202410_df.shape[0]
print(row_count)
# Out:
# 300000

# %%
#export file as csv
sample_202410_df.to_csv("Resources/ny_citibike_202410.csv", index=False, header=True)
